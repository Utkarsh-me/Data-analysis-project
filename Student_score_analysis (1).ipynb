# %% [markdown]
# # PROJECT : Data Analysis Project
# # TITLE : Student Score Analysis
# ### DISCRIPTION :  Here's a project of Student Score Analysis , where we have taken a dataset from kaggle.com. The data is collected from a school. We have analyzed how various factors have a impact on Student's Scores.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#import dataframe_image as dfi

# %% [markdown]
# # Data reading and studying about data

# %%
df = pd.read_csv("student_scores.csv")
df.head()
# Out:
#    Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType TestPrep  \
# 0           0  female         NaN   bachelor's degree      standard     none
# 1           1  female     group C        some college      standard      NaN
# 2           2  female     group B     master's degree      standard     none
# 3           3    male     group A  associate's degree  free/reduced     none
# 4           4    male     group C        some college      standard     none
#
#   ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0             married     regularly          yes         3.0     school_bus
# 1             married     sometimes          yes         0.0            NaN
# 2              single     sometimes          yes         4.0     school_bus
# 3             married         never           no         1.0            NaN
# 4             married     sometimes          yes         0.0     school_bus
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30641 entries, 0 to 30640
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           30641 non-null  int64
#  1   Gender               30641 non-null  object
#  2   EthnicGroup          28801 non-null  object
#  3   ParentEduc           28796 non-null  object
#  4   LunchType            30641 non-null  object
#  5   TestPrep             28811 non-null  object
#  6   ParentMaritalStatus  29451 non-null  object
#  7   PracticeSport        30010 non-null  object
#  8   IsFirstChild         29737 non-null  object
#  9   NrSiblings           29069 non-null  float64
#  10  TransportMeans       27507 non-null  object
#  11  WklyStudyHours       29686 non-null  object
#  12  MathScore            30641 non-null  int64
#  13  ReadingScore         30641 non-null  int64
#  14  WritingScore         30641 non-null  int64
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0    NrSiblings     MathScore  ReadingScore  WritingScore
# count  30641.000000  29069.000000  30641.000000  30641.000000  30641.000000
# mean     499.556607      2.145894     66.558402     69.377533     68.418622
# std      288.747894      1.458242     15.361616     14.758952     15.443525
# min        0.000000      0.000000      0.000000     10.000000      4.000000
# 25%      249.000000      1.000000     56.000000     59.000000     58.000000
# 50%      500.000000      2.000000     67.000000     70.000000     69.000000
# 75%      750.000000      3.000000     78.000000     80.000000     79.000000
# max      999.000000      7.000000    100.000000    100.000000    100.000000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup            1840
# ParentEduc             1845
# LunchType                 0
# TestPrep               1830
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %% [markdown]
# # Drop Unnamed column

# %%
df = df.drop("Unnamed: 0", axis = 1)
df.head()
# Out:
#    Gender EthnicGroup          ParentEduc     LunchType TestPrep  \
# 0  female         NaN   bachelor's degree      standard     none
# 1  female     group C        some college      standard      NaN
# 2  female     group B     master's degree      standard     none
# 3    male     group A  associate's degree  free/reduced     none
# 4    male     group C        some college      standard     none
#
#   ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0             married     regularly          yes         3.0     school_bus
# 1             married     sometimes          yes         0.0            NaN
# 2              single     sometimes          yes         4.0     school_bus
# 3             married         never           no         1.0            NaN
# 4             married     sometimes          yes         0.0     school_bus
#
#   WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0            < 5         71            71            74
# ...

# %%
# dfi.export(d1, 'df_styled.png')

# %% [markdown]
# # gender distribution

# %%
ax = sns.countplot(data= df, x ="Gender", width=0.5)
ax.bar_label(ax.containers[0])
plt.title("Gender distribution")
plt.show()

# %% [markdown]
# #### no. of females is greater than no. of males

# %% [markdown]
# # Boxplots of MathScore , ReadingScore , WritingScore showing Outlyers of scores

# %%
sns.boxplot(data = df, x= "MathScore" )
plt.show()

# %%
sns.boxplot(data = df, x= "ReadingScore" )
plt.show()

# %%
sns.boxplot(data = df, x= "WritingScore" )
plt.show()

# %% [markdown]
# # Distribution of unique values in every columns using visualization

# %% [markdown]
# ### 1. Distribution of Gender

# %%
print(df['Gender'].unique())
# Out:
# ['female' 'male']

# %%
female = df.loc[(df['Gender'] == "female")].count()
male = df.loc[(df['Gender'] == "male")].count()

l1 = ["female", "male"]
g_list = [female['Gender'], male['Gender']]
plt.pie(g_list , labels = l1 , autopct = "%1.2f%%")
plt.title("Distribution of Gender")
plt.show()
print(g_list)
# Out:
# [15424, 15217]

# %% [markdown]
# ### 2. Distribution of Ethnic Groups

# %%
groupA = df.loc[(df['EthnicGroup'] == "group A")].count()
groupB = df.loc[(df['EthnicGroup'] == "group B")].count()
groupC = df.loc[(df['EthnicGroup'] == "group C")].count()
groupD = df.loc[(df['EthnicGroup'] == "group D")].count()
groupE = df.loc[(df['EthnicGroup'] == "group E")].count()

l2 = ["group A", "group B", "group C", "group D", "group E"]
e_list = [groupA['EthnicGroup'] , groupB['EthnicGroup'] , groupC['EthnicGroup'] , groupD['EthnicGroup'] , groupE['EthnicGroup']]
plt.pie(e_list , labels = l2 , autopct = "%1.2f%%")
plt.title("Distribution of Ethnic Group")
plt.show()
print(e_list)
# Out:
# [2219, 5826, 9212, 7503, 4041]

# %%
print(df["EthnicGroup"].unique())
# Out:
# [nan 'group C' 'group B' 'group A' 'group D' 'group E']

# %% [markdown]
# ### 3. Distribution of Parent Education

# %%
print(df['ParentEduc'].unique())
# Out:
# ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school' nan]

# %%
e1 = df.loc[(df['ParentEduc'] == "bachelor's degree")].count()
e2 = df.loc[(df['ParentEduc'] == "some college")].count()
e3 = df.loc[(df['ParentEduc'] == "master's degree")].count()
e4 = df.loc[(df['ParentEduc'] == "associate's degree")].count()
e5 = df.loc[(df['ParentEduc'] == "high school")].count()
e6 = df.loc[(df['ParentEduc'] == "some high school")].count()

l3 =  ["bachelor's degree" , 'some college' ,"master's degree" ,"associate's degree",
 'high school' ,'some high school']
pe_list = [e1['ParentEduc'], e2['ParentEduc'], e3['ParentEduc'], e4['ParentEduc'], e5['ParentEduc'], e6['ParentEduc']]
plt.pie(pe_list , labels = l3 , autopct = "%1.2f%%")
plt.title("Distribution of Parent Education")
plt.show()
print(pe_list)
# Out:
# [3386, 6633, 2023, 5550, 5687, 5517]

# %% [markdown]
# ### 4. Distribution of Lunch Type

# %%
print(df['LunchType'].unique())
# Out:
# ['standard' 'free/reduced']

# %%
std = df.loc[(df['LunchType'] == "standard")].count()
f_r = df.loc[(df['LunchType'] == "free/reduced")].count()

l4 = ["standard", "free/reduced"]
lt_list = [std['LunchType'], f_r['LunchType']]
plt.pie(lt_list , labels = l4 , autopct = "%1.2f%%")
plt.title("Distribution of Lunch Type")
plt.show()
print(lt_list)
# Out:
# [19905, 10736]

# %% [markdown]
# ### 5. Distribution of Test Preparation

# %%
print(df['TestPrep'].unique())
# Out:
# ['none' nan 'completed']

# %%
none = df.loc[(df['TestPrep'] == "none")].count()
completed = df.loc[(df['TestPrep'] == "completed")].count()

l5 = ["none", "completed"]
tp_list = [none['TestPrep'], completed['TestPrep']]
plt.pie(tp_list , labels = l5 , autopct = "%1.2f%%")
plt.title("Distribution of test Preparation")
plt.show()
print(tp_list)
# Out:
# [18856, 9955]

# %% [markdown]
# ### 6. Distribution of Parent Marital Status

# %%
print(df['ParentMaritalStatus'].unique())
# Out:
# ['married' 'single' 'widowed' nan 'divorced']

# %%
mar = df.loc[(df['ParentMaritalStatus'] == "married")].count()
sin = df.loc[(df['ParentMaritalStatus'] == "single")].count()
wid = df.loc[(df['ParentMaritalStatus'] == "widowed")].count()
div = df.loc[(df['ParentMaritalStatus'] == "divorced")].count()

l6 = ["married", "single", "widowed", "divorced"]
pms_list = [mar['ParentMaritalStatus'], sin['ParentMaritalStatus'], wid['ParentMaritalStatus'], div['ParentMaritalStatus']]
plt.pie(pms_list , labels = l6 , autopct = "%1.2f%%")
plt.title("Distribution of Parent Marital Status")
plt.show()
print(pms_list)
# Out:
# [16844, 7097, 591, 4919]

# %% [markdown]
# ### 7.  Distribution of Practice Sport

# %%
print(df['PracticeSport'].unique())
# Out:
# ['regularly' 'sometimes' 'never' nan]

# %%
reg = df.loc[(df['PracticeSport'] == "regularly")].count()
some = df.loc[(df['PracticeSport'] == "sometimes")].count()
never = df.loc[(df['PracticeSport'] == "never")].count()

l7 = ["reg", "some", "never"]
ps_list = [reg['PracticeSport'], some['PracticeSport'], never['PracticeSport']]
plt.pie(ps_list , labels = l7 , autopct = "%1.2f%%")
plt.title("Distribution of Sports Practice")
plt.show()
print(ps_list)
# Out:
# [10793, 15213, 4004]

# %% [markdown]
# ### 8. Distribution of Is first child scenario

# %%
print(df['IsFirstChild'].unique())
# Out:
# ['yes' 'no' nan]

# %%
yes = df.loc[(df['IsFirstChild'] == "yes")].count()
no = df.loc[(df['IsFirstChild'] == "no")].count()

l8 = ["Yes", " No"]
fc_list = [yes['Gender'], no['Gender']]
plt.pie(fc_list , labels = l8 , autopct = "%1.2f%%")
plt.title("Distribution of Is first child scenario")
plt.show()
print(fc_list)
# Out:
# [19082, 10655]

# %% [markdown]
# ### 9. Distribution of no. of siblings

# %%
print(df['NrSiblings'].unique())
# Out:
# [ 3.  0.  4.  1. nan  2.  5.  7.  6.]

# %%
_zero = df.loc[(df['NrSiblings'] == 0.0)].count()
_one = df.loc[(df['NrSiblings'] == 1.0)].count()
_two = df.loc[(df['NrSiblings'] == 2.0)].count()
_three = df.loc[(df['NrSiblings'] == 3.0)].count()
_four = df.loc[(df['NrSiblings'] == 4.0)].count()
_five = df.loc[(df['NrSiblings'] == 5.0)].count()
_six = df.loc[(df['NrSiblings'] == 6.0)].count()
_seven = df.loc[(df['NrSiblings'] == 7.0)].count()

l9 = ["0", "1", "2", "3", "4", "5", "6", "7"]
ns_list = [_zero['NrSiblings'], _one['NrSiblings'], _two['NrSiblings'], _three['NrSiblings'], _four['NrSiblings'], _five['NrSiblings'], _six['NrSiblings'], _seven['NrSiblings']]
plt.pie(ns_list , labels = l9 , autopct = "%1.2f%%" )
plt.title("Distribution of No. of siblings")
plt.show()
print(ns_list)
# Out:
# [3085, 8217, 6790, 6123, 2941, 1320, 302, 291]

# %% [markdown]
# ### 10. Distribution of Transport Means

# %%
print(df['TransportMeans'].unique())
# Out:
# ['school_bus' nan 'private']

# %%
sb = df.loc[(df['TransportMeans'] == "school_bus")].count()
p = df.loc[(df['TransportMeans'] == "private")].count()

l10 = ["school_bus", "private"]
tm_list = [sb['TransportMeans'], p['TransportMeans']]
plt.pie(tm_list , labels = l10 , autopct = "%1.2f%%")
plt.title("Distribution of Transport Means")
plt.show()
print(tm_list)
# Out:
# [16145, 11362]

# %% [markdown]
# ### 11. Distribution of Weekly study Hours

# %%
print(df['WklyStudyHours'].unique())
# Out:
# ['< 5' '5 - 10' '> 10' nan]

# %%
less_5 = df.loc[(df['WklyStudyHours'] == "< 5")].count()
_5_10 = df.loc[(df['WklyStudyHours'] == "5 - 10")].count()
greater10 = df.loc[(df['WklyStudyHours'] == "> 10")].count()

l11 = ["Less than 5 hours", "5 to 10 hours", "Greater than 10 hours"]
wsh_list = [less_5['WklyStudyHours'], _5_10['WklyStudyHours'], greater10['WklyStudyHours']]
plt.pie(wsh_list , labels = l11 , autopct = "%1.2f%%")
plt.title("Distribution of Weekly Study Hours")
plt.show()
print(wsh_list)
# Out:
# [8238, 16246, 5202]

# %% [markdown]
# # 1. Impact of student gender on student score [Gender <--> Scores]

# %%
gb1 = df.groupby("Gender").agg({"MathScore":"mean", "ReadingScore":"mean", "WritingScore":"mean"})
print(gb1)
# Out:
#         MathScore  ReadingScore  WritingScore
# Gender
# female  64.080654     72.853216     72.856457
# male    69.069856     65.854571     63.920418

# %%
sns.heatmap(gb1 , annot = True)
plt.title("Relationaship between parent education and student scores ")
plt.show()

# %%
#Highest score - Lowest score = 
72.856457 - 63.920418
# Out:
# 8.936039000000008

# %% [markdown]
# ### here we conclude that gender have greate impact on students scores

# %% [markdown]
# # 2. Impact of Ethnic Group on student score [Ethnic Group <--> Scores]

# %%
gb11 = df.groupby("EthnicGroup").agg({"MathScore":"mean", "ReadingScore":"mean", "WritingScore":"mean"})
print(gb11)
# Out:
#              MathScore  ReadingScore  WritingScore
# EthnicGroup
# group A      62.991888     66.787742     65.251915
# group B      63.490216     67.320460     65.895125
# group C      64.695723     68.438233     66.999240
# group D      67.666400     70.382247     70.890844
# group E      75.298936     74.251423     72.677060

# %%
sns.heatmap(gb11 , annot = True)
plt.title("Relationaship between Ethnic Group and student scores ")
plt.show()

# %%
#Highest score - Lowest score =
75.298936 - 62.991888
# Out:
# 12.307047999999995

# %% [markdown]
# ### here we conclude that Ethnic Group have greate impact on students scores

# %% [markdown]
# # 3. Impact of Parent Education on students score [Parent Education <--> Scores]

# %%
gb2 = df.groupby("ParentEduc").agg({"MathScore":"mean", "ReadingScore":"mean", "WritingScore":"mean"})
print(gb2)
# Out:
#                     MathScore  ReadingScore  WritingScore
# ParentEduc
# associate's degree  68.365586     71.124324     70.299099
# bachelor's degree   70.466627     73.062020     73.331069
# high school         64.435731     67.213997     65.421136
# master's degree     72.336134     75.832921     76.356896
# some college        66.390472     69.179708     68.501432
# some high school    62.584013     65.510785     63.632409

# %%
sns.heatmap(gb2 , annot = True)
plt.title("Relationaship between parent education and student scores ")
plt.show()

# %%
## Highest score - Lowest score = 
76.356896 - 63.632409
# Out:
# 12.724487000000003

# %% [markdown]
# ### From above heatmap we conclude that parent education have a great impact on student marks

# %% [markdown]
# # 4. Impact of Lunch Type on students score [Lunch type <--> Scores]

# %%
gb3 = df.groupby("LunchType").agg({"MathScore":"mean", "ReadingScore":"mean", "WritingScore":"mean"})
print(gb3)
# Out:
#               MathScore  ReadingScore  WritingScore
# LunchType
# free/reduced  58.862332     64.189735     62.650522
# standard      70.709370     72.175634     71.529716

# %%
sns.heatmap(gb3, annot = True)
plt.title("Impact of Lunch Type on students score [Lunch type <--> Scores]")
plt.show()

# %%
## Highest score - Lowest score = 
70.709370 - 58.862332
# Out:
# 11.847038000000005

# %% [markdown]
# ### From above heatmap we conclude that Lunch Type have a great impact on student marks

# %% [markdown]
# # 5. Impact of Test Preparation on students score [Test Preparation <--> Scores]

# %%
gb4 = df.groupby("TestPrep").agg({"MathScore":"mean", "ReadingScore":"mean", "WritingScore":"mean"})
print(gb4)
# Out:
#            MathScore  ReadingScore  WritingScore
# TestPrep
# completed   69.54666     73.732998     74.703265
# none        64.94877     67.051071     65.092756

# %%
sns.heatmap(gb4, annot = True)
plt.title(" Impact of Test Preparation on students score [Test Preparation <--> Scores]")
plt.show()

# %%
## Highest score - Lowest score =
74.703265 - 65.092756
# Out:
# 9.610509000000008

# %% [markdown]
# ### From above heatmap we conclude that Test Preparation have a good impact on student marks

# %% [markdown]
# # 6. Impact of Parent marital Status on student score [Parent marital Status <--> Scores]

# %%
gb5 = df.groupby("ParentMaritalStatus").agg({"MathScore":"mean", "ReadingScore":"mean", "WritingScore":"mean"})
print(gb5)
# Out:
#                      MathScore  ReadingScore  WritingScore
# ParentMaritalStatus
# divorced             66.691197     69.655011     68.799146
# married              66.657326     69.389575     68.420981
# single               66.165704     69.157250     68.174440
# widowed              67.368866     69.651438     68.563452

# %%
plt.figure(figsize=(5,4))
sns.heatmap(gb5, annot = True)
plt.title("Ralationaship between parent marital status and student scores ")
plt.show()

# %%
## Highest score - Lowest score =
67.368866 - 66.165704
# Out:
# 1.2031619999999918

# %% [markdown]
# ### From above heatmap we conclude that parent marital status have a no/negligible impact on student marks

# %% [markdown]
# # 7. Impact of Sports Practice on student score [Sports Practice <--> Scores]

# %%
gb6 = df.groupby("PracticeSport").agg({"MathScore":"mean", "ReadingScore":"mean", "WritingScore":"mean"})
print(gb6)
# Out:
#                MathScore  ReadingScore  WritingScore
# PracticeSport
# never          64.171079     68.337662     66.522727
# regularly      67.839155     69.943019     69.604003
# sometimes      66.274831     69.241307     68.072438

# %%
sns.heatmap(gb6, annot = True)
plt.title("Impact of Sports Practice on student score [Sports Practice <--> Scores]¶")
plt.show()

# %%
## Highest score - Lowest score =
67.839155 - 64.17107
# Out:
# 3.668085000000005

# %% [markdown]
# ### From above heatmap we conclude that Sports Practice of students have quite impact on student marks

# %% [markdown]
# # 8. Impact of Is First Child scenario on student score [IsFirstChild <--> Scores]

# %%
gb7 = df.groupby("IsFirstChild").agg({"MathScore":"mean", "ReadingScore":"mean", "WritingScore":"mean"})
print(gb7)
# Out:
#               MathScore  ReadingScore  WritingScore
# IsFirstChild
# no            66.246832     69.132614     68.210887
# yes           66.740646     69.542553     68.558484

# %%
sns.heatmap(gb7, annot = True)
plt.title("Impact of Is First Child scenario on student score [IsFirstChild <--> Scores]")
plt.show()

# %%
## Highest score - Lowest score =
66.740646 - 66.246832
# Out:
# 0.4938140000000004

# %% [markdown]
# ### From above heatmap we conclude that Is First child Scenario have a no/negligible impact on student marks

# %% [markdown]
# # 9. Impact of Number of siblings on student score [No. of siblings <--> Scores]

# %%
gb8 = df.groupby("NrSiblings").agg({"MathScore":"mean", "ReadingScore":"mean", "WritingScore":"mean"})
print(gb8)
# Out:
#             MathScore  ReadingScore  WritingScore
# NrSiblings
# 0.0         66.819449     69.547812     68.746515
# 1.0         66.473896     69.259097     68.245345
# 2.0         66.554934     69.472018     68.522533
# 3.0         66.719092     69.488159     68.650498
# 4.0         66.245495     69.144169     68.073444
# 5.0         66.630303     69.453788     68.282576
# 6.0         65.917219     68.801325     67.860927
# 7.0         67.615120     69.828179     68.986254

# %%
sns.heatmap(gb8, annot = True)
plt.title("Ralationaship between no. of siblings and student scores ")
plt.show()

# %%
## Highest score - Lowest score =
68.986254 - 67.860927
# Out:
# 1.1253269999999986

# %% [markdown]
# ### here we conclude that No. of siblings have negligible impact on students scores

# %% [markdown]
# # 10. Impact of Transport Means on student score [Transport Means <--> Scores]

# %%
gb9 = df.groupby("TransportMeans").agg({"MathScore":"mean", "ReadingScore":"mean", "WritingScore":"mean"})
print(gb9)
# Out:
#                 MathScore  ReadingScore  WritingScore
# TransportMeans
# private         66.511354     69.472364     68.509593
# school_bus      66.674636     69.446206     68.492351

# %%
sns.heatmap(gb9, annot = True)
plt.title("Impact of Transport Means on student score [Transport Means <--> Scores]¶")
plt.show()

# %%
## Highest score - Lowest score =
66.674636 - 66.511354
# Out:
# 0.16328200000000948

# %% [markdown]
# ### From above heatmap we conclude that Means of transport have no/negligible impact on student marks

# %% [markdown]
# # 11.Impact of Weekly study hours on student score [WklyStudyHrs <--> Scores]

# %%
gb10 = df.groupby("WklyStudyHours").agg({"MathScore":"mean", "ReadingScore":"mean", "WritingScore":"mean"})
print(gb10)
# Out:
#                 MathScore  ReadingScore  WritingScore
# WklyStudyHours
# 5 - 10          66.870491     69.660532     68.636280
# < 5             64.580359     68.176135     67.090192
# > 10            68.696655     70.365436     69.777778

# %%
sns.heatmap(gb10, annot = True)
plt.title("Impact of Weekly study hours on student score [WklyStudyHrs <--> Scores]¶")
plt.show()

# %%
## Highest score - Lowest score =
70.365436 - 68.176135
# Out:
# 2.1893010000000004

# %% [markdown]
# ### From above heatmap we conclude that Weekly study Hour have quite impact on student marks
